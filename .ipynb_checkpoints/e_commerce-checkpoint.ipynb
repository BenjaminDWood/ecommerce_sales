# %%
import pandas as pd
import datetime as dt

# %% [markdown]
# #### Main Sales Report Table

# %%
data = pd.read_csv('Amazon Sale Report.csv')
df = data.copy()
df.head()
# Out:
# C:\Users\Ben\AppData\Local\Temp\ipykernel_40228\1726645719.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('Amazon Sale Report.csv')
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# ...

# %%
df.columns.values
# Out:
# array(['index', 'Order ID', 'Date', 'Status', 'Fulfilment',
#        'Sales Channel ', 'ship-service-level', 'Style', 'SKU', 'Category',
#        'Size', 'ASIN', 'Courier Status', 'Qty', 'currency', 'Amount',
#        'ship-city', 'ship-state', 'ship-postal-code', 'ship-country',
#        'promotion-ids', 'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype=object)

# %%
df = df.drop(columns='Unnamed: 22')
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... Qty currency  Amount    ship-city   ship-state  \
# ...

# %%
type(df['Date'][0])
# Out:
# str

# %%
df['Date'] = pd.to_datetime(df['Date'], format = '%m-%d-%y')

# %%
type(df['Date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
cols = ['index', 'Order ID', 'Date', 'Status', 'Fulfilment',
       'Sales Channel', 'ship-service-level', 'Style', 'SKU', 'Category',
       'Size', 'ASIN', 'Courier Status', 'Qty', 'currency', 'Amount',
       'ship-city', 'ship-state', 'ship-postal-code', 'ship-country',
       'promotion-ids', 'B2B', 'fulfilled-by']

df.columns = cols

# %%
df.columns.values
# Out:
# array(['index', 'Order ID', 'Date', 'Status', 'Fulfilment',
#        'Sales Channel', 'ship-service-level', 'Style', 'SKU', 'Category',
#        'Size', 'ASIN', 'Courier Status', 'Qty', 'currency', 'Amount',
#        'ship-city', 'ship-state', 'ship-postal-code', 'ship-country',
#        'promotion-ids', 'B2B', 'fulfilled-by'], dtype=object)

# %%
df.dtypes
# Out:
# index                          int64
# Order ID                      object
# Date                  datetime64[ns]
# Status                        object
# Fulfilment                    object
# Sales Channel                 object
# ship-service-level            object
# Style                         object
# SKU                           object
# Category                      object
# Size                          object
# ASIN                          object
# Courier Status                object
# Qty                            int64
# currency                      object
# Amount                       float64
# ship-city                     object
# ship-state                    object
# ship-postal-code             float64
# ship-country                  object
# promotion-ids                 object
# B2B                             bool
# fulfilled-by                  object
# dtype: object

# %%
cols = ['index', 'order_id', 'date', 'status', 'fulfilment',
       'sales_channel', 'ship_service_level', 'style', 'sku', 'category',
       'size', 'asin', 'courier_status', 'qty', 'currency', 'amount',
       'ship_city', 'ship_state', 'ship_postal_code', 'ship_country',
       'promotion_ids', 'b2b', 'fulfilled_by']

# %%
df.columns = cols
df.head()
# Out:
#    index             order_id       date                        status  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146 2022-04-30                       Shipped
# 3      3  403-9615377-8133951 2022-04-30                     Cancelled
# 4      4  407-1069790-7240320 2022-04-30                       Shipped
#
#   fulfilment sales_channel ship_service_level    style              sku  \
# 0   Merchant     Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant     Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon     Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant     Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon     Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         category  ... qty currency  amount    ship_city   ship_state  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 23 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   order_id            128975 non-null  object
#  2   date                128975 non-null  datetime64[ns]
#  3   status              128975 non-null  object
#  4   fulfilment          128975 non-null  object
#  5   sales_channel       128975 non-null  object
#  6   ship_service_level  128975 non-null  object
#  7   style               128975 non-null  object
#  8   sku                 128975 non-null  object
#  9   category            128975 non-null  object
#  10  size                128975 non-null  object
#  11  asin                128975 non-null  object
#  12  courier_status      122103 non-null  object
#  13  qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
from sqlalchemy import create_engine

# %%
username = 'root'
password = 'brandn3w'
host = 'localhost'         # or the {{c1::IP address}}
port = 3306                # default MySQL {{c1::port}}
database = 'ecommerce'  # your {{c1::DB name}}

engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

# %%
df.to_sql('sales_report', con=engine, if_exists='replace', index=False)
# Out:
# 128975

# %% [markdown]
# #### SKU Code Table (item stock)

# %%
data2 = pd.read_csv('Sale Report.csv')
sr = data2.copy()
sr.head()
# Out:
#    index       SKU Code Design No.  Stock       Category Size Color
# 0      0    AN201-RED-L      AN201    5.0  AN : LEGGINGS    L   Red
# 1      1    AN201-RED-M      AN201    5.0  AN : LEGGINGS    M   Red
# 2      2    AN201-RED-S      AN201    3.0  AN : LEGGINGS    S   Red
# 3      3   AN201-RED-XL      AN201    6.0  AN : LEGGINGS   XL   Red
# 4      4  AN201-RED-XXL      AN201    3.0  AN : LEGGINGS  XXL   Red

# %%
sr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9271 entries, 0 to 9270
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       9271 non-null   int64
#  1   SKU Code    9188 non-null   object
#  2   Design No.  9235 non-null   object
#  3   Stock       9235 non-null   float64
#  4   Category    9226 non-null   object
#  5   Size        9235 non-null   object
#  6   Color       9226 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 507.1+ KB

# %%
sr.columns.values
# Out:
# array(['index', 'SKU Code', 'Design No.', 'Stock', 'Category', 'Size',
#        'Color'], dtype=object)

# %%
sr_cols = ['index', 'sku_code', 'design_no', 'stock', 'category', 'size',
       'color']
sr.columns = sr_cols
sr.head()
# Out:
#    index       sku_code design_no  stock       category size color
# 0      0    AN201-RED-L     AN201    5.0  AN : LEGGINGS    L   Red
# 1      1    AN201-RED-M     AN201    5.0  AN : LEGGINGS    M   Red
# 2      2    AN201-RED-S     AN201    3.0  AN : LEGGINGS    S   Red
# 3      3   AN201-RED-XL     AN201    6.0  AN : LEGGINGS   XL   Red
# 4      4  AN201-RED-XXL     AN201    3.0  AN : LEGGINGS  XXL   Red

# %%
sr.to_sql('item_stock', con=engine, if_exists='replace', index=False)
# Out:
# 9271

# %% [markdown]
# #### Customers Table

# %%
data3 = pd.read_csv('International sale Report.csv')
cust = data3.copy()
cust.head()
# Out:
#    index      DATE  Months            CUSTOMER    Style             SKU Size  \
# 0      0  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004    MEN5004-KR-L    L
# 1      1  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004   MEN5004-KR-XL   XL
# 2      2  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004  MEN5004-KR-XXL  XXL
# 3      3  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5009    MEN5009-KR-L    L
# 4      4  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5011    MEN5011-KR-L    L
#
#     PCS    RATE GROSS AMT
# 0  1.00  616.56    617.00
# 1  1.00  616.56    617.00
# 2  1.00  616.56    617.00
# 3  1.00  616.56    617.00
# 4  1.00  616.56    617.00

# %%
cust['CUSTOMER'].nunique()
# Out:
# 172

# %%
cust.columns.values
# Out:
# array(['index', 'DATE', 'Months', 'CUSTOMER', 'Style', 'SKU', 'Size',
#        'PCS', 'RATE', 'GROSS AMT'], dtype=object)

# %%
cols = ['index', 'date', 'months', 'customer', 'style', 'sku', 'size',
       'qty', 'amt', 'gross amt']

cust.columns = cols

# %%
cust.head()
# Out:
#    index      date  months            customer    style             sku size  \
# 0      0  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004    MEN5004-KR-L    L
# 1      1  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004   MEN5004-KR-XL   XL
# 2      2  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004  MEN5004-KR-XXL  XXL
# 3      3  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5009    MEN5009-KR-L    L
# 4      4  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5011    MEN5011-KR-L    L
#
#     qty     amt gross amt
# 0  1.00  616.56    617.00
# 1  1.00  616.56    617.00
# 2  1.00  616.56    617.00
# 3  1.00  616.56    617.00
# 4  1.00  616.56    617.00

# %%
cust = cust.drop(columns = 'months')
cust.head()
# Out:
#    index      date            customer    style             sku size   qty  \
# 0      0  06-05-21  REVATHY LOGANATHAN  MEN5004    MEN5004-KR-L    L  1.00
# 1      1  06-05-21  REVATHY LOGANATHAN  MEN5004   MEN5004-KR-XL   XL  1.00
# 2      2  06-05-21  REVATHY LOGANATHAN  MEN5004  MEN5004-KR-XXL  XXL  1.00
# 3      3  06-05-21  REVATHY LOGANATHAN  MEN5009    MEN5009-KR-L    L  1.00
# 4      4  06-05-21  REVATHY LOGANATHAN  MEN5011    MEN5011-KR-L    L  1.00
#
#       amt gross amt
# 0  616.56    617.00
# 1  616.56    617.00
# 2  616.56    617.00
# 3  616.56    617.00
# 4  616.56    617.00

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37432 entries, 0 to 37431
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      37432 non-null  int64
#  1   date       37431 non-null  object
#  2   customer   36392 non-null  object
#  3   style      36392 non-null  object
#  4   sku        34958 non-null  object
#  5   size       36392 non-null  object
#  6   qty        36392 non-null  object
#  7   amt        36392 non-null  object
#  8   gross amt  36392 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.6+ MB

# %%
cust['date'] = cust['date'].str.strip()

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37432 entries, 0 to 37431
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      37432 non-null  int64
#  1   date       37431 non-null  object
#  2   customer   36392 non-null  object
#  3   style      36392 non-null  object
#  4   sku        34958 non-null  object
#  5   size       36392 non-null  object
#  6   qty        36392 non-null  object
#  7   amt        36392 non-null  object
#  8   gross amt  36392 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.6+ MB

# %%
cust['date'] = pd.to_datetime(cust['date'], errors='coerce', infer_datetime_format=True)
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37432 entries, 0 to 37431
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      37432 non-null  int64
#  1   date       18635 non-null  datetime64[ns]
#  2   customer   36392 non-null  object
#  3   style      36392 non-null  object
#  4   sku        34958 non-null  object
#  5   size       36392 non-null  object
#  6   qty        36392 non-null  object
#  7   amt        36392 non-null  object
#  8   gross amt  36392 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 2.6+ MB
# C:\Users\Ben\AppData\Local\Temp\ipykernel_40228\2713325214.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
# ...

# %%
pd.options.display.max_rows=None
cust['date']
# Out:
# 0       2021-06-05
# 1       2021-06-05
# 2       2021-06-05
# 3       2021-06-05
# 4       2021-06-05
# 5       2021-06-05
# 6       2021-06-05
# 7       2021-06-05
# 8       2021-06-05
# 9       2021-06-05
# 10      2021-06-05
# 11      2021-06-05
# 12      2021-06-05
# 13      2021-06-05
# 14      2021-06-05
# 15      2021-06-05
# 16      2021-06-05
# 17      2021-06-05
# 18      2021-06-05
# 19      2021-06-05
# 20      2021-06-08
# 21      2021-06-08
# 22      2021-06-08
# 23      2021-06-08
# 24      2021-06-08
# 25      2021-06-08
# 26      2021-06-08
# 27      2021-06-08
# 28      2021-06-08
# 29      2021-06-08
# 30      2021-06-08
# 31      2021-06-08
# 32      2021-06-08
# 33      2021-06-08
# 34      2021-06-08
# 35      2021-06-08
# 36      2021-06-08
# 37      2021-06-08
# 38      2021-06-08
# 39      2021-06-08
# 40      2021-06-08
# 41      2021-06-08
# 42      2021-06-08
# 43      2021-06-08
# 44      2021-06-08
# 45      2021-06-08
# 46      2021-06-08
# ...
